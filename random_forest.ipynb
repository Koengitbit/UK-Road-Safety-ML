# %% [markdown]
# # Traffic Accident Random Forest Uitwerking
#
# **Auteurs:** Lars Tovar
# **Opleiding:** HBO-ICT, Hogeschool Windesheim
# **Vak:** Machine Learning
#
# ---
# ## Onderzoeksvraag
#
# **In hoeverre kan de ernst van verkeersongevallen ('Slight', 'Serious' of 'Fatal') in de UK voorspeld worden op basis van omgevings- en wegkenmerken met behulp van Machine Learning?**
# https://www.kaggle.com/datasets/tsiaras/uk-road-safety-accidents-and-vehicles
#
# ### Deelvragen
#
# 1. Welke omgevings- en wegkenmerken uit de dataset zijn belangrijk voor het voorspellen van de ernst van een ongeval?
#
# 2. Welke machine learning-modellen zijn het meest geschikt voor dit classificatieprobleem en hoe verschillen deze modellen in prestaties wanneer rekening wordt gehouden met class imbalance?
#
# 3. Welke combinaties van omgevingsfactoren zijn volgens de modellen het sterkst geassocieerd met ernstige en fatale ongevallen?
#
# 4. Hoe kan de dataset worden voorbereid zodat het geschikt is voor Machine Learning?

# %% [markdown]
# ---
# ## 1. Imports

# %%
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, confusion_matrix, balanced_accuracy_score
import numpy as np
import matplotlib.pyplot as plt
from sklearn.experimental import enable_halving_search_cv
from sklearn.model_selection import HalvingRandomSearchCV, StratifiedKFold
from sklearn.utils import resample

# %% [markdown]
# ---
# ## 2. Data Laden
# De data is al opgesplitst in de EDA notebook. We laden hier de train, validatie en testsets in. De `.squeeze()` zorgt ervoor dat de y-kolom als een Series wordt ingeladen ipv een DataFrame, dit is nodig voor sklearn.

# %%
X_train_df = pd.read_csv("train_set.csv")
X_val_df   = pd.read_csv("validation_set.csv")
X_test_df  = pd.read_csv("test_set.csv")

y_train = pd.read_csv("y_train.csv").squeeze()  # omzetten naar 1D Series voor sklearn compatibility
y_val   = pd.read_csv("y_val.csv").squeeze()
y_test  = pd.read_csv("y_test.csv").squeeze()

# %% [markdown]
# ---
# ## 3. Random Forest
# Een Random Forest maakt meerdere beslisbomen en combineert de uitkomsten door te kijken wat de meerderheid zegt. Dit werkt beter dan een enkele boom omdat het minder snel overfit.
#
# We gebruiken `class_weight='balanced'` omdat er veel meer Slight ongelukken in de dataset zitten dan Serious of Fatal. Zonder dit zou het model alles als Slight bestempelen en alsnog een hoge accuracy halen. We gebruiken 200 bomen en `max_features='sqrt'` zodat elke boom een andere subset van features bekijkt.

# %%
rf = RandomForestClassifier(
    n_estimators=200,
    random_state=42,
    n_jobs=-1,
    class_weight="balanced",  # class imbalance verbeteren
    max_features="sqrt"
)

rf.fit(X_train_df, y_train)
# Out:
# RandomForestClassifier(class_weight='balanced', n_estimators=200, n_jobs=-1,
#                        random_state=42)

# %% [markdown]
# ---
# ## 4. Evaluatie op de validatieset
# We evalueren het model op de validatieset. We gebruiken balanced accuracy omdat gewone accuracy niet informatief is bij een scheve klassenverdeling.

# %%
y_val_pred = rf.predict(X_val_df)  # voorspellingen op de validation set

print("VAL Balanced accuracy:", balanced_accuracy_score(y_val, y_val_pred))
print("\nVAL Classification report:\n")
print(classification_report(y_val, y_val_pred, digits=4))
print("\nVAL Confusion matrix:\n")
print(confusion_matrix(y_val, y_val_pred))
# Out:
# VAL Balanced accuracy: 0.3350312604278262
#
# VAL Classification report:
#
#               precision    recall  f1-score   support
#
#            0     0.8479    0.9958    0.9159    346910
#            1     0.2514    0.0087    0.0168     57268
#            2     0.0612    0.0006    0.0011      5273
#
#     accuracy                         0.8449    409451
#    macro avg     0.3868    0.3350    0.3113    409451
# weighted avg     0.7544    0.8449    0.7784    409451
#
#
# VAL Confusion matrix:
#
# [[345463   1414     33]
#  [ 56757    498     13]
#  [  5201     69      3]]

# %% [markdown]
# De balanced accuracy is 0.34, wat laag is. De recall voor Serious is 0.009 en voor Fatal 0.001, het model gooit dus alles op Slight. We gaan proberen dit te verbeteren door de hyperparameters te tunen.

# %% [markdown]
# ---
# ## 5. Tuning
#
# We tunen de hyperparameters met `HalvingRandomSearchCV`. Deze methode probeert eerst veel combinaties op een klein deel van de data en gooit elke ronde de slechtste eruit. Dit is efficiënter dan een volledige grid search bij grote datasets.
#
# **Waarom een sample van 200.000 rijen?** De volledige trainingset is te groot voor een uitgebreide hyperparameter search met cross-validation. Een gestratificeerde sample van 200.000 rijen (gebaseerd op jaar × severity) is groot genoeg om representatief te zijn voor de datadistributie, maar klein genoeg om de rekentijd beheersbaar te houden.
#
# **Welke hyperparameters en waarom deze ranges?**
# - **`max_depth`** (10, 20, 30, None): bepaalt hoe diep een boom mag groeien. Te ondiep = underfitting (de boom kan complexe patronen niet leren), te diep = overfitting (de boom past zich te veel aan op de trainingsdata). We testen een breed bereik inclusief onbeperkte diepte.
# - **`min_samples_split`** (2, 5, 10): het minimumaantal samples dat nodig is om een node te splitsen. Hogere waarden voorkomen dat de boom te specifiek wordt op kleine groepen data.
# - **`max_features`** ('sqrt', 'log2', 0.3): hoeveel features elke boom mag bekijken per split. Minder features per split verhoogt de diversiteit tussen bomen en vermindert overfitting.
#
# **Waarom `f1_macro` als scoring-metric?** Bij class imbalance is gewone accuracy misleidend (een model dat alles als Slight voorspelt haalt al ~84% accuracy). Macro F1 weegt elke klasse even zwaar: het berekent de F1-score per klasse en neemt het ongewogen gemiddelde. Hierdoor worden Serious en Fatal even belangrijk als Slight tijdens het tunen, wat precies is wat we willen bij een ongebalanceerde dataset.

# %%
from sklearn.utils import resample

stratify_col = X_train_df["Year"].astype(str) + "_" + y_train.astype(str)

X_sample, y_sample = resample(
    X_train_df, y_train,
    n_samples=200_000,
    stratify=stratify_col,
    random_state=42
)

print("\nSample verdeling per klasse:")
print(y_sample.value_counts().sort_index())

param_dist = {
    "max_depth": [10, 20, 30, None],
    "min_samples_split": [2, 5, 10],
    "max_features": ["sqrt", "log2", 0.3],
}

cv = StratifiedKFold(n_splits=3, shuffle=True, random_state=42)

# basis random forest model voor tunen
rf_base = RandomForestClassifier(
    n_estimators=100,       # vast tijdens tuning
    bootstrap=True,
    random_state=42,
    n_jobs=-1,
    class_weight="balanced"
)

# halving random search uitvoeren op de sample dataset
search = HalvingRandomSearchCV(
    estimator=rf_base,
    param_distributions=param_dist,
    n_candidates=30,
    min_resources="smallest",
    factor=3,
    scoring="f1_macro",
    cv=cv,
    n_jobs=-1,
    random_state=42,
    verbose=1,
    refit=True
)

search.fit(X_sample, y_sample)

print("Best params:", search.best_params_)
print("Best CV f1_macro:", search.best_score_)

# model trainen met de beste parameters
best_rf = RandomForestClassifier(
    **search.best_params_,
    n_estimators=200,
    random_state=42,
    n_jobs=-1,
    class_weight="balanced"
)
best_rf.fit(X_train_df, y_train)
# Out:
# Sample verdeling per klasse:
# Accident_Severity
# 0    169452
# 1     27973
# 2      2575
# Name: count, dtype: int64
# n_iterations: 4
# n_required_iterations: 4
# n_possible_iterations: 9
# min_resources_: 18
# max_resources_: 200000
# aggressive_elimination: False
# factor: 3
# ----------
# iter: 0
# n_candidates: 30
# n_resources: 18
# Fitting 3 folds for each of 30 candidates, totalling 90 fits
# ----------
# iter: 1
# n_candidates: 10
# n_resources: 54
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# ----------
# iter: 2
# n_candidates: 4
# n_resources: 162
# Fitting 3 folds for each of 4 candidates, totalling 12 fits
# ----------
# iter: 3
# n_candidates: 2
# n_resources: 486
# Fitting 3 folds for each of 2 candidates, totalling 6 fits
# Best params: {'min_samples_split': 5, 'max_features': 'log2', 'max_depth': 30}
# Best CV f1_macro: 0.3661460715174442
# RandomForestClassifier(class_weight='balanced', max_depth=30,
# ...

# %% [markdown]
# ---
# ## 5b. Evaluatie na Tuning
# We evalueren het getunede model op de validatieset om te kijken of de resultaten zijn verbeterd.

# %%
y_val_pred = best_rf.predict(X_val_df)

print("VAL Balanced accuracy:", balanced_accuracy_score(y_val, y_val_pred))
print("\nVAL Classification report:\n")
print(classification_report(y_val, y_val_pred, digits=4))
print("\nVAL Confusion matrix:\n")
print(confusion_matrix(y_val, y_val_pred))
# Out:
# VAL Balanced accuracy: 0.3991735767337186
#
# VAL Classification report:
#
#               precision    recall  f1-score   support
#
#            0     0.8608    0.8948    0.8775    346910
#            1     0.2113    0.1098    0.1445     57268
#            2     0.0533    0.1929    0.0836      5273
#
#     accuracy                         0.7760    409451
#    macro avg     0.3751    0.3992    0.3685    409451
# weighted avg     0.7596    0.7760    0.7648    409451
#
#
# VAL Confusion matrix:
#
# [[310427  22921  13562]
#  [ 46494   6289   4485]
#  [  3696    560   1017]]

# %% [markdown]
# De balanced accuracy is nu **0.40**, een verbetering ten opzichte van de 0.34 zonder tuning. De macro F1 is **0.37**. De gewone accuracy is 0.78, maar dat komt vooral door de class imbalance, een model dat alles als Slight voorspelt haalt ook al ~84% accuracy, dus accuracy is hier geen goede maatstaf.
#
# **Opmerking over metriekkeuze:** Dit is een *classificatieprobleem* (drie discrete klassen), geen regressieprobleem. Regressiemetrieken zoals R², MAE of MSE zijn hier niet van toepassing. De relevante metrieken voor de spreiding van prestaties over klassen zijn precision, recall en F1 per klasse, plus de confusion matrix.
#
# ### Prestaties per klasse
#
# **Slight (klasse 0)**, precision 0.861, recall 0.895. Wordt goed voorspeld omdat dit veruit de grootste klasse is (~84% van alle data). Het model heeft voldoende voorbeelden om de patronen van lichte ongevallen te leren.
#
# **Serious (klasse 1)**, precision 0.211, recall 0.110. Het model mist de meeste Serious-ongevallen en als het Serious voorspelt, klopt het vaak niet. Dit is de moeilijkste klasse: Serious-ongevallen zitten qua kenmerken "tussen" Slight en Fatal in, waardoor het model ze niet goed kan onderscheiden van de andere twee klassen.
#
# **Fatal (klasse 2)**, precision 0.053, recall 0.193. Fatal wordt nu wel opgepikt (verbetering t.o.v. het basismodel waar Fatal nooit voorspeld werd), maar de precision is zeer laag: er zijn veel false positives.
#
# ### Analyse van de confusion matrix: waar komen de fouten vandaan?
#
# De confusion matrix onthult het kernprobleem:
# - **Slight** wordt meestal correct geclassificeerd, maar een deel wordt ten onrechte als Serious of Fatal bestempeld.
# - **Serious** wordt overwegend als Slight misclassificeerd. Dit is logisch: Serious-ongevallen delen veel kenmerken met Slight-ongevallen (vergelijkbare wegen, tijdstippen, weersomstandigheden), waardoor het model ze niet goed kan onderscheiden.
# - **Fatal** wordt in een deel van de gevallen correct herkend, maar er worden ook veel Slight- en Serious-ongevallen foutief als Fatal voorspeld. Het model probeert Fatal te vangen door agressiever te voorspellen (dankzij `class_weight='balanced'`), maar dit gaat ten koste van de precision.
#
# ### Waarom is dit zo moeilijk?
#
# De fundamentele uitdaging is dat de kenmerken van een ongeval (wegtype, snelheid, weer, etc.) slechts een deel van de ernst bepalen. Factoren zoals de exacte positie van inzittenden, het dragen van gordels, en het type botsing zijn niet beschikbaar in deze dataset. Bovendien maakt de extreme class imbalance (Fatal is <2% van de data) het voor het model bijzonder lastig om deze klasse goed te leren.
#
# **Mogelijke verbeteringen:** meer agressieve class weighting, oversampling technieken zoals SMOTE voor de minderheidklassen, of een andere drempelwaarde (threshold) voor de klasse-voorspellingen.

# %% [markdown]
# ---
# ## 6. Eindevaluatie op de testset
# De testset is tot nu toe niet aangeraakt. We gebruiken deze voor de laatste evaluatie om te kijken hoe het model presteert op compleet nieuwe data.

# %%
y_test_pred = best_rf.predict(X_test_df)

print("TEST Balanced accuracy:", balanced_accuracy_score(y_test, y_test_pred))
print("\nTEST Classification report:\n")
print(classification_report(y_test, y_test_pred, digits=4))
print("\nTEST Confusion matrix:\n")
print(confusion_matrix(y_test, y_test_pred))
# Out:
# TEST Balanced accuracy: 0.39796930093400906
#
# TEST Classification report:
#
#               precision    recall  f1-score   support
#
#            0     0.8612    0.8952    0.8779    346910
#            1     0.2122    0.1104    0.1453     57268
#            2     0.0521    0.1883    0.0816      5274
#
#     accuracy                         0.7763    409452
#    macro avg     0.3752    0.3980    0.3683    409452
# weighted avg     0.7600    0.7763    0.7652    409452
#
#
# TEST Confusion matrix:
#
# [[310553  22825  13532]
#  [ 46409   6324   4535]
#  [  3629    652    993]]

# %% [markdown]
# De balanced accuracy is 0.40 en de macro F1 is 0.37, dit komt overeen met de validatieset. Het model generaliseert goed en er is geen sprake van overfitting. De prestaties per klasse zijn ook vergelijkbaar met de validatieset.

# %% [markdown]
# ---
# ## 7. Conclusie
#
# ### 7.1 Feature Importance
#
# Voordat we concluderen, bekijken we welke features het meest bijdragen aan de voorspellingen. De feature importance (Gini-based) geeft aan hoeveel elke feature gemiddeld bijdraagt aan het splitsen van de data in de beslisbomen. Hogere waarden betekenen dat de feature meer invloed heeft. Anders dan bij logistische regressie krijg je hier geen score per klasse, maar een totaalscore per feature.

# %%
importances = pd.Series(best_rf.feature_importances_, index=X_train_df.columns)
top20 = importances.sort_values(ascending=False).head(20)
print(top20)
# Out:
# Latitude                                   0.152006
# Longitude                                  0.151082
# Hour                                       0.112659
# Year                                       0.093427
# DayOfWeek_fromDate                         0.073655
# Speed_limit                                0.060603
# Urban_or_Rural_Area_Urban                  0.031892
# Pedestrian_Crossing-Physical_Facilities    0.023482
# 1st_Road_Class_Unclassified                0.017888
# 1st_Road_Class_B                           0.013891
# Light_Conditions_Daylight                  0.012697
# Road_Surface_Conditions_Dry                0.011734
# Road_Surface_Conditions_Wet or damp        0.011618
# Light_Conditions_Darkness - no lighting    0.010807
# 1st_Road_Class_C                           0.010714
# Weather_Conditions_Fine no high winds      0.010709
# 2nd_Road_Class_Unclassified                0.010125
# 2nd_Road_Class_Unknown                     0.009716
# ...

# %%
top20.sort_values().plot(kind='barh', figsize=(10, 8), color='steelblue')
plt.title("Top 20 Feature Importances - Random Forest")
plt.xlabel("Importance score")
plt.tight_layout()
plt.show()

# %% [markdown]
# **Latitude**, **Longitude** en **Hour** staan bovenaan, locatie en tijdstip zijn de belangrijkste factoren. Year en DayOfWeek zitten ook in de top 5, gevolgd door **Speed_limit** en **Urban_or_Rural_Area**.
#
# Dit sluit aan bij de bevindingen uit de EDA: snelheidslimieten, lichtcondities en de urban/rural-verdeling waren de sterkste categorische predictors. Dat locatiegegevens (Lat/Long) zo dominant zijn is opvallend en verdient een kritische kanttekening, zie de conclusie hieronder.

# %% [markdown]
# ### 7.2 Samenvatting en beantwoording deelvragen
#
# **Modelprestaties:**
# Zonder tuning had het model een balanced accuracy van 0.34 en voorspelde vrijwel alles als Slight. Na tuning met `HalvingRandomSearchCV` (best: max_depth=30, max_features='log2', min_samples_split=5) steeg de balanced accuracy naar **0.40** op zowel validatie- als testset, met een macro F1 van **0.37**. Het feit dat de testprestaties overeenkomen met de validatieprestaties bevestigt dat het model niet overfit.
#
# ---
#
# **Deelvraag 1: Welke omgevings- en wegkenmerken zijn belangrijk voor het voorspellen van de ernst?**
#
# De feature importance analyse toont dat **locatie (Latitude, Longitude)**, **tijdstip (Hour)**, **Speed_limit** en **Urban_or_Rural_Area** de belangrijkste features zijn. Dit sluit aan bij de EDA-bevindingen: hogere snelheidslimieten, landelijke gebieden en nachtelijke uren zijn geassocieerd met ernstigere ongevallen.
#
# **Deelvraag 2: Hoe presteert het Random Forest model bij class imbalance?**
#
# Het Random Forest model met `class_weight='balanced'` en hyperparameter tuning behaalt een balanced accuracy van 0.40 en macro F1 van 0.37. Slight-ongevallen worden goed voorspeld (recall 0.90), maar Serious (recall 0.11) en Fatal (recall 0.19) blijven lastig. De extreme class imbalance (Fatal <2% van de data) maakt het inherent moeilijk om deze klassen nauwkeurig te voorspellen.
#
# **Deelvraag 3: Welke combinaties van factoren zijn het sterkst geassocieerd met ernstige en fatale ongevallen?**
#
# Het Random Forest model biedt via feature importance een globaal beeld: locatie, tijd en snelheidslimiet zijn dominant. Het model kan niet direct combinaties tonen (daarvoor zou SHAP-analyse nodig zijn), maar de EDA toonde al dat combinaties zoals Rural + hoge snelheid + duisternis de hoogste fatal-percentages hebben.
#
# **Deelvraag 4: Hoe kan de dataset worden voorbereid voor ML?**
#
# De datavoorbereiding uit de EDA (one-hot encoding, mediaan-imputing, standaardisering, stratified train/val/test split) bleek effectief. Het model kon succesvol worden getraind op de 71 resulterende features.
#
# ---
#
# ### 7.3 Limitaties
#
# - **Dominantie van locatiefeatures:** Latitude en Longitude zijn de belangrijkste features. Dit roept de vraag op of het model daadwerkelijk de *omstandigheden* van een ongeval leert, of simpelweg de *geografie* van het VK (bepaalde regio's hebben structureel meer fatale ongevallen door hogere snelheidslimieten en landelijke wegen). Een vervolgexperiment zonder locatiefeatures zou dit kunnen verhelderen.
# - **Klasse-onbalans:** Ondanks `class_weight='balanced'` blijft het model moeite houden met de minderheidklassen. Technieken zoals SMOTE (oversampling van minderheidklassen) of threshold-optimalisatie zouden de recall van Serious en Fatal kunnen verbeteren.
# - **Ontbrekende informatie:** De dataset bevat geen informatie over voertuigkenmerken (bijv. type voertuig, leeftijd van het voertuig), bestuurdergedrag (gordel, alcohol) of de exacte aard van de botsing. Deze factoren hebben waarschijnlijk een groot effect op de ernst.
#
# ### 7.4 Aanbevelingen voor vervolg
#
# - **SHAP-analyse** uitvoeren om per voorspelling te begrijpen welke features bijdragen, in plaats van alleen globale importance.
# - **Locatiefeatures verwijderen** als experiment om te testen of het model nog steeds voorspellend is op basis van pure omgevingskenmerken.
# - **Vergelijking met logistische regressie** om te zien welk model beter presteert en waar de sterke punten van elk model liggen.
# - **Threshold-optimalisatie:** in plaats van de standaard argmax, een threshold kiezen die de recall van Fatal maximaliseert (ten koste van precision), als het doel is om fatale ongevallen zo volledig mogelijk te detecteren.
